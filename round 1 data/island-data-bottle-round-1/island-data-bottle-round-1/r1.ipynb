# %%
import pandas

# %%
pandas.read_csv('trades_round_1_day_-2_nn.csv', sep=';')
# Out:
#       timestamp  buyer  seller   symbol   currency   price  quantity
# 0             0    NaN     NaN  BANANAS  SEASHELLS  5003.0         1
# 1             0    NaN     NaN   PEARLS  SEASHELLS  9996.0         1
# 2             0    NaN     NaN   PEARLS  SEASHELLS  9996.0         1
# 3          1100    NaN     NaN  BANANAS  SEASHELLS  4998.0         1
# 4          1300    NaN     NaN  BANANAS  SEASHELLS  5000.0         4
# ...         ...    ...     ...      ...        ...     ...       ...
# 5335     997700    NaN     NaN   PEARLS  SEASHELLS  9996.0         1
# 5336     998000    NaN     NaN  BANANAS  SEASHELLS  4946.0         1
# 5337     998200    NaN     NaN  BANANAS  SEASHELLS  4945.0        20
# 5338     998900    NaN     NaN  BANANAS  SEASHELLS  4951.0         1
# 5339     999800    NaN     NaN   PEARLS  SEASHELLS  9998.0         1
#
# [5340 rows x 7 columns]

# %%
pandas.read_csv('prices_round_1_day_-1.csv', sep=';')
# Out:
#        day  timestamp  product  bid_price_1  bid_volume_1  bid_price_2  \
# 0       -1          0   PEARLS        10002             1       9996.0
# 1       -1          0  BANANAS         4951             1       4946.0
# 2       -1        100   PEARLS         9996             2       9995.0
# 3       -1        100  BANANAS         4945            24          NaN
# 4       -1        200  BANANAS         4945            20          NaN
# ...    ...        ...      ...          ...           ...          ...
# 19995   -1     999700   PEARLS         9995            26          NaN
# 19996   -1     999800  BANANAS         4891            20          NaN
# 19997   -1     999800   PEARLS         9995            20          NaN
# 19998   -1     999900  BANANAS         4892            31          NaN
# 19999   -1     999900   PEARLS         9996             2       9995.0
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
pandas.read_csv('prices_round_1_day_0.csv', sep=';')
# Out:
#        day  timestamp  product  bid_price_1  bid_volume_1  bid_price_2  \
# 0        0          0   PEARLS         9998             1       9995.0
# 1        0          0  BANANAS         4893             1       4892.0
# 2        0        100   PEARLS         9996             1       9995.0
# 3        0        100  BANANAS         4892            31          NaN
# 4        0        200   PEARLS         9996             1       9995.0
# ...    ...        ...      ...          ...           ...          ...
# 19995    0     999700  BANANAS         4875             1       4870.0
# 19996    0     999800   PEARLS         9995            27          NaN
# 19997    0     999800  BANANAS         4869            27          NaN
# 19998    0     999900   PEARLS         9996             2       9995.0
# 19999    0     999900  BANANAS         4870            23          NaN
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...
